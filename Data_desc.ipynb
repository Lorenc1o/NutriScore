# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import nutrscore data
nutrscore = pd.read_csv("data.csv", sep=";")
df = pd.DataFrame(nutrscore)
df
# Out:
#                 id                                            name nutriscore
# 0         20267605                                        Anacardi          b  \
# 1         20006105                              Roggenvollkornbrot          a
# 2    8008698007303                 SCHAR - Fette crocantinis schar          c
# 3    5202390015878      Violife 100% vegan original flavour slices          e
# 4    5010044010045                 21 seeds and grains thin bagels          a
# ..             ...                                             ...        ...
# 187  7613031473113                                  SHREDDED WHEAT          a
# 188  8714685903229                  Falafels De Patates Douces BIO          b
# 189  3033710038381                                 Nescafé classic          e
# 190         336789                      Spinach Ricotta Tortelloni          b
# 191  5053827199728  Trésor Kellogg's Choco Roulette offre spéciale          e
#
#        energy  fat_g  sugar_g  sodium_mg  perc_fruit  fibers_g  proteins_g
# 0    2510.400   47.6      6.5        8.0       76.29       5.2        20.5
# 1     878.640    1.8      3.9      400.0       60.24       9.3         5.8
# 2    1589.920    1.7      6.0      560.0       91.65       2.3         6.0
# 3    1192.440   23.0      0.0      920.0       78.96       0.0         0.0
# 4    1121.312    2.4      4.7      340.0       52.78       3.5        10.6
# ..        ...    ...      ...        ...         ...       ...         ...
# 187  1506.240    2.2      0.7       20.0       78.49      12.2        12.2
# 188   711.280    9.7      4.0      320.0       94.57       0.0         6.0
# 189     4.184    0.0      0.0        0.0       73.69       0.0         0.2
# 190   673.624    3.3      1.4      140.0       53.43       1.7         6.3
# 191  1874.432    0.0      0.0        0.0       66.06       0.0         0.0
#
# [192 rows x 10 columns]

# %%
#print 10 prod
df.head(10)
# Out:
#               id                                        name nutriscore
# 0       20267605                                    Anacardi          b  \
# 1       20006105                          Roggenvollkornbrot          a
# 2  8008698007303             SCHAR - Fette crocantinis schar          c
# 3  5202390015878  Violife 100% vegan original flavour slices          e
# 4  5010044010045             21 seeds and grains thin bagels          a
# 5        1167078                            Cannellini Beans          e
# 6  5000129339987                                 Bran flakes          a
# 7  4088600295350                           Multigrain shapes          b
# 8  4056489147855                            Seeded flatbread          b
# 9         819350                       German style rye loaf          e
#
#       energy   fat_g  sugar_g  sodium_mg  perc_fruit  fibers_g  proteins_g
# 0  2510.4000  47.600    6.500        8.0       76.29      5.20       20.50
# 1   878.6400   1.800    3.900      400.0       60.24      9.30        5.80
# 2  1589.9200   1.700    6.000      560.0       91.65      2.30        6.00
# 3  1192.4400  23.000    0.000      920.0       78.96      0.00        0.00
# 4  1121.3120   2.400    4.700      340.0       52.78      3.50       10.60
# 5   361.0792   0.513    0.427       10.3       65.00      5.47        6.41
# 6  1518.7920   2.800   10.000      256.0       74.88     13.00       11.00
# 7  1627.5760   2.600   14.000       52.0       81.58      0.00        8.40
# 8  1447.6640   9.300    2.500      360.0       71.95      0.00       10.90
# 9   907.9280   0.000    0.000        0.0       73.76      0.00        0.00

# %%
df.shape
# Out:
# (192, 10)

# %%
#data distribution without id
df.drop('id', axis=1).hist(bins=50, figsize=(20,15))
df.describe()
# Out:
#                  id       energy       fat_g     sugar_g     sodium_mg
# count  1.920000e+02   192.000000  192.000000  192.000000    192.000000  \
# mean   4.542582e+12  1141.938739   11.092950    6.453935    392.455961
# std    2.466979e+12   791.533241   16.469177    9.960908   1362.636072
# min    3.367890e+05     4.184000    0.000000    0.000000      0.000000
# 25%    4.056489e+12   363.275800    1.500000    0.775000     32.000000
# 50%    5.014214e+12  1167.336000    3.000000    3.200000    120.000000
# 75%    5.411188e+12  1608.748000   13.000000    5.900000    440.000000
# max    9.352042e+12  3447.616000   91.600000   57.000000  17840.000000
#
#        perc_fruit    fibers_g  proteins_g
# count  192.000000  192.000000  192.000000
# mean    69.121302    4.363642    7.851580
# std     15.794215    4.673527    6.951489
# min      2.800000    0.000000    0.000000
# 25%     60.227500    0.500000    1.925000
# 50%     68.290000    3.100000    6.800000
# 75%     79.835000    7.391667   11.000000
# max    100.000000   27.000000   34.000000

# %%
# show distribution of all items for nurtscore_grade, order by grade with different colors
sns.countplot(x='nutriscore', data=df, order=['a','b','c','d','e'])
# df['nutriscore'].value_counts().plot(kind='bar')
plt.show()
